# %% [markdown]
# # Testing access to a Key vault secret
#
# This notebook demonstrates how to access a secret stored in Azure Key Vault using the Azure SDK for Python.
#
# Install the Microsoft Entra identity library and Key Vault secrets library:

# %%
# %pip install azure-identity 
# %pip install azure-keyvault-secrets
# Out:
# Requirement already satisfied: azure-identity in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (1.24.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-identity) (1.37.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-identity) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-identity) (1.33.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-identity) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# Collecting azure-keyvault-secrets
#   Downloading azure_keyvault_secrets-4.10.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-keyvault-secrets) (0.7.2)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-keyvault-secrets) (1.37.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-keyvault-secrets) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from azure-core>=1.31.0->azure-keyvault-secrets) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hodellai\appdata\local\miniconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (2025.4.26)
# Downloading azure_keyvault_secrets-4.10.0-py3-none-any.whl (125 kB)
# Installing collected packages: azure-keyvault-secrets
# Successfully installed azure-keyvault-secrets-4.10.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You will need get the Key Vault URI and the secret name. You can get these values from the Azure portal or using Terraform outputs as shown below:

# %%
import os

os.environ["NO_PROXY"] = "*"

# Capture terraform output into a Python variable (string)
keyvault_uri = ! terraform output -raw keyvault_uri
keyvault_uri = keyvault_uri.n

print("keyvault_uri:", keyvault_uri)

keyvault_secret_name = ! terraform output -raw keyvault_secret_name
keyvault_secret_name = keyvault_secret_name.n

print("keyvault_secret_name:", keyvault_secret_name)
# Out:
# keyvault_uri: https://keyvault270-dev.vault.azure.net/
# keyvault_secret_name: secret-password

# %% [markdown]
# Now you can use the following code to access the secret:

# %%
from azure.keyvault.secrets import SecretClient
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()
client = SecretClient(vault_url=keyvault_uri, credential=credential)

print(f"Retrieving your secret {keyvault_secret_name} from {keyvault_uri}...")

retrieved_secret = client.get_secret(keyvault_secret_name)

print(f"Your secret is '{retrieved_secret.value}'.")
# Out:
# Retrieving your secret secret-password from https://keyvault270-dev.vault.azure.net/...
# Your secret is '@Aa123456789'.
